# %%
pip install oauth2client
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 98.2/98.2 kB 2.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#기본세팅
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from oauth2client.tools import argparser
import pandas as pd

# %%
#유튜브 API 키 인증
DEVELOPER_KEY= 'AIzaSyA8J3yfnLLLAwMlqU78jAXA9rq8N4ACWXY'
YOUTUBE_API_SERVICE_NAME='youtube'
YOUTUBE_API_VERSION='v3'

youtube = build(
  YOUTUBE_API_SERVICE_NAME,
  YOUTUBE_API_VERSION,
  developerKey=DEVELOPER_KEY
  )

API_KEY = 'AIzaSyA8J3yfnLLLAwMlqU78jAXA9rq8N4ACWXY'

# %%
#유투브 댓글 조회 
response = (
    youtube
    .commentThreads()
    .list(
      part='snippet,replies', 
      videoId='iFnIPPorydo', 
      maxResults=100
      )
    .execute()
    )
items = len(response.get('items'))

comments = {
    'commentor' :  [response.get('items')[i].get('snippet').get('topLevelComment').get('snippet').get('authorDisplayName') for i in range(items)],
    'comments' : [response.get('items')[i].get('snippet').get('topLevelComment').get('snippet').get('textOriginal') for i in range(items)]
}

comments = pd.DataFrame(comments)

# %%
type(comments)
# Out:
# pandas.core.frame.DataFrame

# %%
items = len(response.get('items'))

comments = {
    'commentor' :  [response.get('items')[i].get('snippet').get('topLevelComment').get('snippet').get('authorDisplayName') for i in range(items)],
    'comments' : [response.get('items')[i].get('snippet').get('topLevelComment').get('snippet').get('textOriginal') for i in range(items)]
}

comments = pd.DataFrame(comments)

# %%
response = (
    youtube
    .commentThreads()
    .list(
      part='snippet,replies', 
      videoId='iFnIPPorydo', 
      maxResults=100
      )
    .execute()
    )

items = len(response.get('items'))

comments = {
    'commentor' :  [response.get('items')[i].get('snippet').get('topLevelComment').get('snippet').get('authorDisplayName') for i in range(items)],
    'comments' : [response.get('items')[i].get('snippet').get('topLevelComment').get('snippet').get('textOriginal') for i in range(items)]
}

comments = pd.DataFrame(comments)

while 'nextPageToken' in response:
  response = (
    youtube
    .commentThreads()
    .list(
      part='snippet,replies',
      videoId='iFnIPPorydo',
      pageToken=response.get('nextPageToken'),
      maxResults=100
      )
    .execute()
    ) 
  items = len(response.get('items'))

  comment = {
        'commentor' :  [response.get('items')[i].get('snippet').get('topLevelComment').get('snippet').get('authorDisplayName') for i in range(items)],
        'comments' : [response.get('items')[i].get('snippet').get('topLevelComment').get('snippet').get('textOriginal') for i in range(items)]
    }
  comments = comments.append(pd.DataFrame(comment))
# Out:
# C:\Users\관리자\AppData\Local\Temp\ipykernel_11480\2702453075.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comments = comments.append(pd.DataFrame(comment))
# C:\Users\관리자\AppData\Local\Temp\ipykernel_11480\2702453075.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comments = comments.append(pd.DataFrame(comment))
# C:\Users\관리자\AppData\Local\Temp\ipykernel_11480\2702453075.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comments = comments.append(pd.DataFrame(comment))
# C:\Users\관리자\AppData\Local\Temp\ipykernel_11480\2702453075.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
response = (
    youtube
    .commentThreads()
    .list(
      part='snippet,replies', 
      videoId='iFnIPPorydo', 
      maxResults=100
      )
    .execute()
    )

items = len(response.get('items'))

comments = {
    'commentor' :  [response.get('items')[i].get('snippet').get('topLevelComment').get('snippet').get('authorDisplayName') for i in range(items)],
    'comments' : [response.get('items')[i].get('snippet').get('topLevelComment').get('snippet').get('textOriginal') for i in range(items)]
}

comments = pd.DataFrame(comments)

while 'nextPageToken' in response:
  response = (
    youtube
    .commentThreads()
    .list(
      part='snippet,replies',
      videoId='iFnIPPorydo',
      pageToken=response.get('nextPageToken'),
      maxResults=100
      )
    .execute()
    ) 
  items = len(response.get('items'))

  comment = {
        'commentor' :  [response.get('items')[i].get('snippet').get('topLevelComment').get('snippet').get('authorDisplayName') for i in range(items)],
        'comments' : [response.get('items')[i].get('snippet').get('topLevelComment').get('snippet').get('textOriginal') for i in range(items)]
    }
  comments = comments.append(pd.DataFrame(comment))
# Out:
# C:\Users\관리자\AppData\Local\Temp\ipykernel_11480\2702453075.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comments = comments.append(pd.DataFrame(comment))
# C:\Users\관리자\AppData\Local\Temp\ipykernel_11480\2702453075.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comments = comments.append(pd.DataFrame(comment))
# C:\Users\관리자\AppData\Local\Temp\ipykernel_11480\2702453075.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comments = comments.append(pd.DataFrame(comment))
# C:\Users\관리자\AppData\Local\Temp\ipykernel_11480\2702453075.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
