# %%
import re
import time
import pandas as pd
import json
import requests
import FinanceDataReader as fdr
import numpy as np
import seaborn as sns
import math
from bs4 import BeautifulSoup
from tqdm import tqdm
from datetime import datetime

# %%
df = pd.read_csv('./AL_41_D161_20221228.csv', encoding='cp949')
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_20308\2820298592.py:1: DtypeWarning: Columns (7,8,9,10,17,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./AL_41_D161_20221228.csv', encoding='cp949')

# %%
df
# Out:
#                          고유번호       법정동코드              법정동명  대장구분코드 대장구분명  \
# 0         4111112900100010000  4111112900   경기도 수원시 장안구 파장동       1  토지대장
# 1         4111112900100020000  4111112900   경기도 수원시 장안구 파장동       1  토지대장
# 2         4111112900100020001  4111112900   경기도 수원시 장안구 파장동       1  토지대장
# 3         4111112900100020002  4111112900   경기도 수원시 장안구 파장동       1  토지대장
# 4         4111112900100030000  4111112900   경기도 수원시 장안구 파장동       1  토지대장
# ...                       ...         ...               ...     ...   ...
# 14258338  4183041033200460000  4183041033  경기도 양평군 개군면 상자포리       2  임야대장
# 14258339  4183041033200460000  4183041033  경기도 양평군 개군면 상자포리       2  임야대장
# 14258340  4183041033200460001  4183041033  경기도 양평군 개군면 상자포리       2  임야대장
# 14258341  4183041033200460004  4183041033  경기도 양평군 개군면 상자포리       2  임야대장
# 14258342  4183041033200470000  4183041033  경기도 양평군 개군면 상자포리       2  임야대장
#
#             지번  집합건물일련번호  건물동명  건물층명  건물호명  ... 소유구분  거주지구분코드   거주지구분  \
# ...

# %%
df = df[df['법정동명'].str.contains('안성시', na =False)]

# %%
df1 = df[df['법정동명'].str.contains('원곡면', na =False)]
df2 = df[df['법정동명'].str.contains('양성면', na =False)]

# %%
df1.to_csv('Anseong_onegok.csv', index=False, encoding='utf-8-sig')

# %%
df2.to_csv('Anseong_yangseong.csv', index=False, encoding='utf-8-sig')

# %%
df.to_csv('Anseong.csv', index=False, encoding='utf-8-sig')
